# %%
import wave
import os
import scipy.io.wavfile as wav
import matplotlib.pyplot as plt

# %%
for file_name in os.listdir('.'):
    print(f"File: {file_name}")
    if not file_name.endswith('.wav'):
        continue
    with wave.open(file_name, 'rb') as audio_file:
        print(f"File: {file_name}")
        channels = audio_file.getnchannels()
        sample_width = audio_file.getsampwidth()
        frame_rate = audio_file.getframerate()
        bit_rate_bps = channels * sample_width * 8 * frame_rate
        # Convert to kbps
        bit_rate_kbps = bit_rate_bps / 1000
        print(f"Channels: {channels}")
        print(f"Sample Width: {sample_width}")
        print(f"Frame Rate (Sample Rate): {audio_file.getframerate()}")
        print(f"Bit Rate: {bit_rate_kbps} kbps")
        print(f"Number of Frames: {audio_file.getnframes()}")
        print(f"Compression Type: {audio_file.getcomptype()} \n")
        #if bit_rate_kbps <2000:
        #   os.remove(file_name)
# Out:
# File: 01b_trumpet.wav
# File: 01b_trumpet.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 507150
# Compression Type: NONE
#
# File: 02_violin.wav
# File: 02_violin.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 441000
# Compression Type: NONE
#
# File: 11_guitar.wav
# File: 11_guitar.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 441000
# Compression Type: NONE
#
# File: 20c_accordion.wav
# File: 20c_accordion.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 529207
# Compression Type: NONE
#
# File: 23_jazz.wav
# File: 23_jazz.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 441000
# Compression Type: NONE
#
# File: accordion_Auditorium.wav
# File: accordion_Auditorium.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 557106
# Compression Type: NONE
#
# File: accordion_Movie_Theater.wav
# File: accordion_Movie_Theater.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 546937
# Compression Type: NONE
#
# File: accordion_small_office.wav
# File: accordion_small_office.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 544289
# Compression Type: NONE
#
# File: guitar_Auditorium.wav
# File: guitar_Auditorium.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 468899
# Compression Type: NONE
#
# File: guitar_Movie_Theater.wav
# File: guitar_Movie_Theater.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 458730
# Compression Type: NONE
#
# File: guitar_small_office.wav
# File: guitar_small_office.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 456082
# Compression Type: NONE
#
# File: Jazz_Auditorium.wav
# File: Jazz_Auditorium.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 468899
# Compression Type: NONE
#
# File: Jazz_Movie_Theater.wav
# File: Jazz_Movie_Theater.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 458730
# Compression Type: NONE
#
# File: Jazz_small_office.wav
# File: Jazz_small_office.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 456082
# Compression Type: NONE
#
# File: properties.ipynb
# File: Trumpet_Auditorium.wav
# File: Trumpet_Auditorium.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 535049
# Compression Type: NONE
#
# File: Trumpet_Movie_Theater.wav
# File: Trumpet_Movie_Theater.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 524880
# Compression Type: NONE
#
# File: Trumpet_small_office.wav
# File: Trumpet_small_office.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 522232
# Compression Type: NONE
#
# File: violin_Auditorium.wav
# File: violin_Auditorium.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 468899
# Compression Type: NONE
#
# File: violin_Movie_Theater.wav
# File: violin_Movie_Theater.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 458730
# Compression Type: NONE
#
# File: violin_small_office.wav
# File: violin_small_office.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 456082
# Compression Type: NONE

# %%
import os
from pydub import AudioSegment

if not AudioSegment.converter:
    raise RuntimeError("FFmpeg is not installed or not found in system PATH.")

for file_name in os.listdir('.'):
    print(f"File: {file_name}")
    if not file_name.endswith('.wav'):
        continue
    audio = AudioSegment.from_file(file_name)
    
    channels = audio.channels
    sample_width = audio.sample_width
    frame_rate = audio.frame_rate
    bit_rate_bps = channels * sample_width * 8 * frame_rate
    # Convert to kbps
    bit_rate_kbps = bit_rate_bps / 1000
    print(f"Channels: {channels}")
    print(f"Sample Width: {sample_width}")
    print(f"Frame Rate (Sample Rate): {frame_rate}")
    print(f"Bit Rate: {bit_rate_kbps} kbps")
    print(f"Number of Frames: {len(audio)}")  # Pydub uses length in milliseconds
    print(f"Compression Type: {audio_file.getcomptype()} \n")
    print(f"Compression Type: {audio.sample_width * 8}-bit PCM \n")  # Assuming PCM
# Out:
# File: 01b_trumpet.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 11500
# Compression Type: NONE
#
# Compression Type: 16-bit PCM
#
# File: 02_violin.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 10000
# Compression Type: NONE
#
# Compression Type: 16-bit PCM
#
# File: 11_guitar.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 10000
# Compression Type: NONE
#
# Compression Type: 16-bit PCM
#
# File: 20c_accordion.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 12000
# Compression Type: NONE
#
# Compression Type: 16-bit PCM
#
# File: 23_jazz.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 10000
# Compression Type: NONE
#
# Compression Type: 16-bit PCM
#
# File: accordion_Auditorium.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 12633
# Compression Type: NONE
#
# Compression Type: 16-bit PCM
#
# File: accordion_Movie_Theater.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 12402
# Compression Type: NONE
#
# Compression Type: 16-bit PCM
#
# File: accordion_small_office.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 12342
# Compression Type: NONE
#
# Compression Type: 16-bit PCM
#
# File: guitar_Auditorium.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 10633
# Compression Type: NONE
#
# Compression Type: 16-bit PCM
#
# File: guitar_Movie_Theater.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 10402
# Compression Type: NONE
#
# Compression Type: 16-bit PCM
#
# File: guitar_small_office.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 10342
# Compression Type: NONE
#
# Compression Type: 16-bit PCM
#
# File: Jazz_Auditorium.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 10633
# Compression Type: NONE
#
# Compression Type: 16-bit PCM
#
# File: Jazz_Movie_Theater.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 10402
# Compression Type: NONE
#
# Compression Type: 16-bit PCM
#
# File: Jazz_small_office.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 10342
# Compression Type: NONE
#
# Compression Type: 16-bit PCM
#
# File: properties.ipynb
# File: Trumpet_Auditorium.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 12133
# Compression Type: NONE
#
# Compression Type: 16-bit PCM
#
# File: Trumpet_Movie_Theater.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 11902
# Compression Type: NONE
#
# Compression Type: 16-bit PCM
#
# File: Trumpet_small_office.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 11842
# Compression Type: NONE
#
# Compression Type: 16-bit PCM
#
# File: violin_Auditorium.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 10633
# Compression Type: NONE
#
# Compression Type: 16-bit PCM
#
# File: violin_Movie_Theater.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 10402
# Compression Type: NONE
#
# Compression Type: 16-bit PCM
#
# File: violin_small_office.wav
# Channels: 2
# Sample Width: 2
# Frame Rate (Sample Rate): 44100
# Bit Rate: 1411.2 kbps
# Number of Frames: 10342
# Compression Type: NONE
#
# Compression Type: 16-bit PCM

# %%
for filename in os.listdir("."):
    if filename.endswith(".wav"):
        print("Processing file: "+filename)
        
        fs, data = wav.read(filename)
        plt.figure()
        plt.plot(data[:,0])
        plt.title(f"The {filename} sound")
# Out:
# Processing file: 01b_trumpet.wav
# Processing file: 02_violin.wav
# Processing file: 11_guitar.wav
# Processing file: 20c_accordion.wav
# C:\Users\abuma\AppData\Local\Temp\ipykernel_184556\3383648532.py:5: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   fs, data = wav.read(filename)
# Processing file: 23_jazz.wav
# Processing file: accordion_Auditorium.wav
# Processing file: accordion_Movie_Theater.wav
# Processing file: accordion_small_office.wav
# Processing file: guitar_Auditorium.wav
# Processing file: guitar_Movie_Theater.wav
# Processing file: guitar_small_office.wav
# Processing file: Jazz_Auditorium.wav
# Processing file: Jazz_Movie_Theater.wav
# Processing file: Jazz_small_office.wav
# Processing file: Trumpet_Auditorium.wav
# Processing file: Trumpet_Movie_Theater.wav
# Processing file: Trumpet_small_office.wav
# Processing file: violin_Auditorium.wav
# Processing file: violin_Movie_Theater.wav
# Processing file: violin_small_office.wav
